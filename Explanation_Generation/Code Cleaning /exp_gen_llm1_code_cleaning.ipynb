# %% [markdown]
# # New Cleaned Code

# %%
import pandas as pd
import ast
import tokenize
from io import StringIO
import textwrap
import re
import autopep8

# --- Patch legacy Python 2 exceptions ---
def fix_legacy_exception_syntax(code: str) -> str:
    return re.sub(r'except\s+(\w+)\s*,\s*(\w+):', r'except \1 as \2:', code)

# --- Fallback: Regex-based docstring remover ---
def remove_docstrings_fallback(code: str) -> str:
    return re.sub(r'(""".*?"""|\'\'\'.*?\'\'\')', '', code, flags=re.DOTALL)

# --- Robust AST-based docstring remover with fallback ---
def remove_docstrings(source_code: str) -> str:
    source_code = fix_legacy_exception_syntax(source_code)
    lines = source_code.splitlines()
    try:
        tree = ast.parse(source_code)
    except SyntaxError:
        return remove_docstrings_fallback(source_code)

    for node in ast.walk(tree):
        if isinstance(node, (ast.FunctionDef, ast.AsyncFunctionDef, ast.ClassDef, ast.Module)):
            if not node.body:
                continue
            first_stmt = node.body[0]
            if (
                isinstance(first_stmt, ast.Expr)
                and isinstance(first_stmt.value, ast.Constant)
                and isinstance(first_stmt.value.value, str)
            ):
                start = first_stmt.lineno - 1
                end = getattr(first_stmt, 'end_lineno', start + len(first_stmt.value.value.splitlines()))
                for i in range(start, end):
                    if 0 <= i < len(lines):
                        lines[i] = ''
    return '\n'.join(lines)

# --- Remove all `#` comments with robust indentation fixing ---
def remove_all_comments(code: str) -> str:
    attempts = 0
    max_attempts = 1
    # Try tokenizing; if an IndentationError occurs, try to fix the code's indentation
    while attempts < max_attempts:
        try:
            io_obj = StringIO(code)
            tokens = list(tokenize.generate_tokens(io_obj.readline))
            break  # Successful tokenization, exit the loop.
        except IndentationError as e:
            attempts += 1
            code = autopep8.fix_code(code)
    else:
        # If still failing after max_attempts, return the code unchanged.
        return code

    output = ""
    last_lineno = -1
    last_col = 0
    for tok in tokens:
        token_type, token_string, start, end, _ = tok
        if token_type == tokenize.COMMENT:
            continue
        sline, scol = start
        eline, ecol = end
        if sline > last_lineno:
            output += "\n" * (sline - last_lineno - 1)
            last_col = 0
        if scol > last_col:
            output += " " * (scol - last_col)
        output += token_string
        last_lineno = eline
        last_col = ecol
    return output

# --- Remove extra blank lines ---
def remove_extra_blank_lines(code: str) -> str:
    cleaned_lines = []
    previous_blank = False
    for line in code.splitlines():
        if line.strip() == "":
            if not previous_blank:
                cleaned_lines.append("")
                previous_blank = True
        else:
            cleaned_lines.append(line.rstrip())
            previous_blank = False
    return "\n".join(cleaned_lines)

# --- Fix indentation using autopep8 ---
def fix_indentation(code: str) -> str:
    return autopep8.fix_code(code)

# --- Full pipeline ---
def split_code_and_comments(source_code: str) -> str:
    # First, fix indentation issues.
    source_code = fix_indentation(source_code)
    source_code = textwrap.dedent(source_code)
    no_docstrings = remove_docstrings(source_code)
    no_comments = remove_all_comments(no_docstrings)
    final_code = remove_extra_blank_lines(no_comments)
    return final_code

def clean_code_column(input_csv: str, code_column: str = "code"):
    df = pd.read_csv(input_csv)
    df["cleaned_code"] = df[code_column].apply(split_code_and_comments)
    return df

# --- Step 6: Run it ---
if __name__ == "__main__":
    input_path = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/raw_data_CSN/CodeSearchNet_Python_train.csv"
    df = clean_code_column(input_path)
    output_path = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/pre_processing_CSN/CodeSearchNet_Python_train_cleaned.csv"
    df.to_csv(output_path, index=False)
    print(f"Cleaned CSV written to: {output_path}")
# Out:
# <string>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <string>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <string>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <string>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'NoneType' object is not callable; perhaps you missed a comma?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <string>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Traceback (most recent call last):
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 101
#     df = clean_code_column(input_path)
#
#   Cell In[14], line 95 in clean_code_column
#     df["cleaned_code"] = df[code_column].apply(split_code_and_comments)
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/pandas/core/series.py:4917 in apply
#     return SeriesApply(
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/pandas/core/apply.py:1427 in apply
#     return self.apply_standard()
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/pandas/core/apply.py:1507 in apply_standard
#     mapped = obj._map_values(
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/pandas/core/base.py:921 in _map_values
#     return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/pandas/core/algorithms.py:1743 in map_array
#     return lib.map_infer(values, mapper, convert=convert)
#
#   File lib.pyx:2972 in pandas._libs.lib.map_infer
#
#   Cell In[14], line 89 in split_code_and_comments
#     no_comments = remove_all_comments(no_docstrings)
#
#   Cell In[14], line 49 in remove_all_comments
#     for tok in tokenize.generate_tokens(io_obj.readline):
#
#   File ~/.conda/envs/gpu-env/lib/python3.9/tokenize.py:512 in _tokenize
#     raise IndentationError(
#
#   File <tokenize>:11
#     self._hypernode_attributes[hypernode] = attr_dict
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # Flag for failed records

# %%
import pandas as pd
import ast
import tokenize
from io import StringIO
import textwrap
import re
import autopep8
import time
from tqdm import tqdm

# --- Patch legacy Python 2 exceptions ---
def fix_legacy_exception_syntax(code: str) -> str:
    return re.sub(r'except\s+(\w+)\s*,\s*(\w+):', r'except \1 as \2:', code)

# --- Fallback: Regex-based docstring remover ---
def remove_docstrings_fallback(code: str) -> str:
    return re.sub(r'(""".*?"""|\'\'\'.*?\'\'\')', '', code, flags=re.DOTALL)

# --- Robust AST-based docstring remover with fallback ---
def remove_docstrings(source_code: str) -> str:
    source_code = fix_legacy_exception_syntax(source_code)
    lines = source_code.splitlines()
    try:
        tree = ast.parse(source_code)
    except SyntaxError:
        return remove_docstrings_fallback(source_code)

    for node in ast.walk(tree):
        if isinstance(node, (ast.FunctionDef, ast.AsyncFunctionDef, ast.ClassDef, ast.Module)):
            if not node.body:
                continue
            first_stmt = node.body[0]
            if (
                isinstance(first_stmt, ast.Expr)
                and isinstance(first_stmt.value, ast.Constant)
                and isinstance(first_stmt.value.value, str)
            ):
                start = first_stmt.lineno - 1
                end = getattr(first_stmt, 'end_lineno', start + len(first_stmt.value.value.splitlines()))
                for i in range(start, end):
                    if 0 <= i < len(lines):
                        lines[i] = ''
    return '\n'.join(lines)

# --- Remove all `#` comments with robust indentation fixing ---
def remove_all_comments(code: str) -> (str, bool):

    attempts = 0
    max_attempts = 1
    failed = False
    while attempts < max_attempts:
        try:
            io_obj = StringIO(code)
            tokens = list(tokenize.generate_tokens(io_obj.readline))
            break  # Successful tokenization, exit loop.
        except:
            attempts += 1
            code = autopep8.fix_code(code)
    else:
        # If we exceed max_attempts, flag the issue and return code unchanged.
        failed = True
        return code, failed

    # Build code output from tokens, skipping those with type COMMENT.
    output = ""
    last_lineno = -1
    last_col = 0
    for tok in tokens:
        token_type, token_string, start, end, _ = tok
        if token_type == tokenize.COMMENT:
            continue
        sline, scol = start
        eline, ecol = end
        if sline > last_lineno:
            output += "\n" * (sline - last_lineno - 1)
            last_col = 0
        if scol > last_col:
            output += " " * (scol - last_col)
        output += token_string
        last_lineno = eline
        last_col = ecol
    return output, failed

# --- Remove extra blank lines ---
def remove_extra_blank_lines(code: str) -> str:
    cleaned_lines = []
    previous_blank = False
    for line in code.splitlines():
        if line.strip() == "":
            if not previous_blank:
                cleaned_lines.append("")
                previous_blank = True
        else:
            cleaned_lines.append(line.rstrip())
            previous_blank = False
    return "\n".join(cleaned_lines)

# --- Fix indentation using autopep8 ---
def fix_indentation(code: str) -> str:
    return autopep8.fix_code(code)

# --- Full pipeline ---
def split_code_and_comments(source_code: str) -> (str, bool):
    # First, fix indentation issues and dedent
    source_code = fix_indentation(source_code)
    source_code = textwrap.dedent(source_code)
    # Remove docstrings
    no_docstrings = remove_docstrings(source_code)
    # Remove inline comments and get flag
    no_comments, flag = remove_all_comments(no_docstrings)
    # Remove extra blank lines
    final_code = remove_extra_blank_lines(no_comments)
    return final_code, flag

def clean_code_column(input_csv: str, code_column: str = "code"):
    df = pd.read_csv(input_csv)
    cleaned_codes = []
    flags = []
    for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
        final_code, flag = split_code_and_comments(str(row[code_column]))
        cleaned_codes.append(final_code)
        flags.append(flag)
    df["cleaned_code"] = cleaned_codes
    # Record indices where remove_all_comments returned code unchanged (flag True)
    df["remove_all_comments_issue"] = flags
    return df

# --- Step 6: Run it ---
if __name__ == "__main__":
    input_path = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/raw_data_CSN/CodeSearchNet_Python_train.csv"
    start = time.time()
    df = clean_code_column(input_path)
    output_path = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/pre_processing_CSN/CodeSearchNet_Python_train_cleaned.csv"
    df.to_csv(output_path, index=False)
    end = time.time()
    print(f"Cleaned CSV written to: {output_path} in {end-start} seconds")
# Out:
#   1%|          | 1923/251820 [03:37<7:50:06,  8.86it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 137
#     135 input_path = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/raw_data_CSN/CodeSearchNet_Python_train.csv"
#     136 start = time.time()
# --> 137 df = clean_code_column(input_path)
#     138 output_path = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/pre_processing_CSN/CodeSearchNet_Python_train_cleaned.csv"
#     139 df.to_csv(output_path, index=False)
#
# Cell In[1], line 124, in clean_code_column(input_csv, code_column)
#     122 cleaned_codes = []
#     123 flags = []
# --> 124 for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
#     125     final_code, flag = split_code_and_comments(str(row[code_column]))
#     126     cleaned_codes.append(final_code)
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/std.py:1191, in tqdm.__iter__(self)
#    1189 dt = cur_t - last_print_t
#    1190 if dt >= mininterval and cur_t >= min_start_t:
# -> 1191     self.update(n - last_print_n)
#    1192     last_print_n = self.last_print_n
#    1193     last_print_t = self.last_print_t
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/std.py:1242, in tqdm.update(self, n)
#    1240     self._ema_dn(dn)
#    1241     self._ema_dt(dt)
# -> 1242 self.refresh(lock_args=self.lock_args)
#    1243 if self.dynamic_miniters:
#    1244     # If no `miniters` was specified, adjust automatically to the
#    1245     # maximum iteration rate seen so far between two prints.
#    1246     # e.g.: After running `tqdm.update(5)`, subsequent
#    1247     # calls to `tqdm.update()` will only cause an update after
#    1248     # at least 5 more iterations.
#    1249     if self.maxinterval and dt >= self.maxinterval:
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/std.py:452, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
# --> 452     fp.write(str(s))
#     453     fp_flush()
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/tqdm/utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/ipykernel/iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/ipykernel/iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/ipykernel/iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File ~/.conda/envs/gpu-env/lib/python3.9/site-packages/zmq/sugar/socket.py:707, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     700         data = zmq.Frame(
#     701             data,
#     702             track=track,
#     703             copy=copy or None,
#     704             copy_threshold=self.copy_threshold,
#     705         )
#     706     data.group = group
# --> 707 return super().send(data, flags=flags, copy=copy, track=track)
#
# File _zmq.py:1092, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1140, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1339, in zmq.backend.cython._zmq._send_copy()
#
# File _zmq.py:160, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:

# %%
import pandas as pd
import ast
import tokenize
from io import StringIO

def validate_comments(code: str):
    
    # --- Check for inline comment tokens ---
    has_comment = False
    comment_tokens = []
    try:
        tokens = list(tokenize.generate_tokens(StringIO(code).readline))
    except Exception as e:
        comment_tokens.append(f"Tokenization error: {e}")
        has_comment = True
    else:
        for token in tokens:
            if token.type == tokenize.COMMENT:
                has_comment = True
                comment_tokens.append(token.string)
    
    # --- Check for docstrings via AST ---
    has_docstring = False
    docstrings = []
    try:
        tree = ast.parse(code)
        for node in ast.walk(tree):
            if isinstance(node, (ast.Module, ast.FunctionDef, ast.AsyncFunctionDef, ast.ClassDef)):
                ds = ast.get_docstring(node, clean=False)
                if ds is not None:
                    has_docstring = True
                    docstrings.append(ds)
    except Exception as e:
        docstrings.append(f"AST parse error: {e}")
        has_docstring = True

    return has_comment, comment_tokens, has_docstring, docstrings

def validate_cleaned_code(csv_file: str, code_column: str = "cleaned_code"):
    
    df = pd.read_csv(csv_file)
    results = []
    for i, row in df.iterrows():
        code = str(row[code_column])
        has_comment, comment_tokens, has_docstring, docstrings = validate_comments(code)
        if has_comment or has_docstring:
            results.append({
                "row": i,
                "has_comment": has_comment,
                "comment_tokens": comment_tokens,
                "has_docstring": has_docstring,
                "docstrings": docstrings
            })
    return results

if __name__ == "__main__":
    # Path to cleaned CSV file 
    csv_file = "/work/pi_wenlongzhao_umass_edu/27/anamikaghosh/pre_processing_CSN/CodeSearchNet_Python_train_cleaned.csv"

    
    # Validate the cleaned code column.
    problems = validate_cleaned_code(csv_file, code_column="cleaned_code")
    
    if not problems:
        print("All rows have been successfully cleaned: no inline comments or docstrings were found!")
    else:
        print("Some rows still contain comments or docstrings:")
        for p in problems:
            print(f"Row {p['row']}:")
            if p["has_comment"]:
                print(f"  Comments found: {p['comment_tokens']}")
            if p["has_docstring"]:
                print(f"  Docstrings found: {p['docstrings']}")
# Out:
# ⚠️ Some rows still contain comments or docstrings:
# Row 1318:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 14)']
# Row 1322:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 37)']
# Row 1507:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Illegal URL resource address.\\n")? (<unknown>, line 11)']
# Row 1519:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Bad choice for interpolate:", interpolate)? (<unknown>, line 6)']
# Row 1547:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('WARNING: Empty -',uri)? (<unknown>, line 6)"]
# Row 2011:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 2016:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 4172:
#   Docstrings found: ["# Convert size to list if it isn't already\n    if not isinstance(size, list):\n        size = list(size)\n    # If a single value was supplied use it for all 3 axes\n    if len(size) == 1:\n        size = [size[0], size[0], size[0]]"]
# Row 4176:
#   Docstrings found: ["# Convert size to list if it isn't already\n    if not isinstance(size, list):\n        size = list(size)\n    # If a single value was supplied use it for all 3 axes\n    if len(size) == 1:\n        size = [size[0], size[0], size[0]]"]
# Row 4188:
#   Docstrings found: ["# Convert value to list if it isn't already\n    if not isinstance(value, list):\n        value = list(value)\n    # If a single value was supplied use it for all 3 axes\n    if len(value) == 1:\n        value = [value[0], value[0], value[0]]"]
# Row 4190:
#   Docstrings found: ["vert_function(s=s, x='(%s+y-taper)*sin(x/(%s+y))' % (radius, radius),\n                     y='(%s+y)*cos(x/(%s+y))' % (radius, radius),\n                     z='z-%s*x/(2*%s*(%s+y))' % (pitch, pi, radius))"]
# Row 4230:
#   Docstrings found: ['\n    i = u[1]*v[2] - u[2]*v[1]\n    j = u[2]*v[0] - u[0]*v[2]\n    k = u[0]*v[1] - u[1]*v[0]\n    ']
# Row 5430:
#   Docstrings found: ['0x88   outputs on\n              + 8 bytes - user code\n              + 16/32 bytes - output list\n              If function is accepted, function result can be\n              checked by observe the system state ']
# Row 5518:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 17)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 17)']
# Row 5686:
#   Docstrings found: ["AST parse error: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: malformed \\N character escape (<unknown>, line 8)"]
# Row 6614:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 6780:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 11)']
# Row 6781:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Getting members.')? (<unknown>, line 4)"]
# Row 6782:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Getting teams.')? (<unknown>, line 4)"]
# Row 6783:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Getting repos.')? (<unknown>, line 4)"]
# Row 6787:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Hit search limit. Sleeping for 60 sec.')? (<unknown>, line 9)"]
# Row 6788:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Hit search limit. Sleeping for 60 sec.')? (<unknown>, line 5)"]
# Row 6800:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Getting organization.')? (<unknown>, line 7)"]
# Row 6805:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Getting traffic.')? (<unknown>, line 4)"]
# Row 6817:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Logging in.")? (<unknown>, line 28)']
# Row 6818:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Getting members\\' emails.')? (<unknown>, line 4)"]
# Row 6840:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 9)']
# Row 7837:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 8)']
# Row 8767:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 8768:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 8996:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 8997:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9251:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9252:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9254:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9256:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9258:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("dragmove!")? (<unknown>, line 24)']
# Row 9267:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("down!")? (<unknown>, line 4)']
# Row 9268:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("move!")? (<unknown>, line 4)']
# Row 9269:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 2)']
# Row 9270:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("KEY:", key)? (<unknown>, line 33)']
# Row 9271:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("deleting", obj.name)? (<unknown>, line 7)']
# Row 9272:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("duplicating", obj.name)? (<unknown>, line 8)']
# Row 9287:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("COLOR", value, value.default)? (<unknown>, line 8)']
# Row 9288:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("adding to sizer:", child.name)? (<unknown>, line 5)']
# Row 9289:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("reparenting", ctrl.name)? (<unknown>, line 7)']
# Row 9293:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Searching modules in", rootpath)? (<unknown>, line 9)']
# Row 9301:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("val", val, row, col, self.startValue)? (<unknown>, line 6)']
# Row 9315:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 37)']
# Row 9330:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 31)']
# Row 9331:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 6)']
# Row 9333:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 11)']
# Row 9335:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("inspect child", child)? (<unknown>, line 5)']
# Row 9337:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("update child", child, kwargs)? (<unknown>, line 6)']
# Row 9616:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9617:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9618:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9619:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9620:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9621:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9622:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9623:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 11)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 11)']
# Row 9624:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9625:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 9626:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9627:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9628:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9629:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9630:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9631:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9632:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 8)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 8)']
# Row 9633:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9634:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 8)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 8)']
# Row 9635:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 9636:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9637:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9638:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 8)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 8)']
# Row 9639:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9640:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9720:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9721:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 8)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 8)']
# Row 9722:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 9723:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 9724:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 9725:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9726:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9727:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 9728:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 9729:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 10052:
#   Docstrings found: [' if product in field_names:\n            field = field_names[product]\n        elif isinstance(product, inventory.Product):\n            return\n        else:\n            field = None ']
# Row 10162:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 12)']
# Row 10286:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10287:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10288:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10290:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10291:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 8)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 8)']
# Row 10292:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10293:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10294:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 10295:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10296:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 9)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 9)']
# Row 10297:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10298:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 10299:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 10505:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Using insert size: %d" % mean)? (<unknown>, line 21)']
# Row 10588:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 7)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 7)']
# Row 10626:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 10683:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10779:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10792:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 10828:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Adding tool: %s" % tool)? (<unknown>, line 9)']
# Row 10841:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 4)']
# Row 10842:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 10848:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 11)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 11)']
# Row 10851:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("error parsing: %s" % dlg.path)? (<unknown>, line 17)']
# Row 10884:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Could not open %s." % file_or_filename)? (<unknown>, line 10)']
# Row 10912:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("X1/Y1:", name, x1, y1)? (<unknown>, line 10)']
# Row 10913:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("POS:", x, y, self.component.position)? (<unknown>, line 9)']
# Row 11042:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Map      ', self.map)? (<unknown>, line 4)"]
# Row 11048:
#   Docstrings found: ['In this function, the best would to create labels each time we need to create one,\n        following the number of labels in label_information.\n        #self.essai = QtGui.QLabel(self.ui.tab)\n        #self.essai.setGeometry(PyQt4.QtCore.QRect(870,650,111,16))\n        #self.essai.setText("ESSAI")\n        ']
# Row 11051:
#   Docstrings found: ['\n        Error when planarRad start : /bin/sh: 1: ../planarrad.py: not found\n        ']
# Row 11052:
#   Docstrings found: ["\n        This function needs to be tested. We don't know if she works.\n        "]
# Row 11053:
#   Docstrings found: ['\n        Nothing programmed for displaying a message box when the user clicks on the window cross in order to quit.\n        ']
# Row 11054:
#   Docstrings found: ['\n        Increment the name of the figure in order to not erase the previous figure if the user use always this method.\n        The png file is put in the "Artists_saved" file localized in the "planarradpy" folder.\n        ']
# Row 11055:
#   Docstrings found: ['\n        TO DO.\n        ']
# Row 11056:
#   Docstrings found: ['\n        TO DO.\n        ']
# Row 11073:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("in slow transport deliver")? (<unknown>, line 6)']
# Row 11121:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("CMake  is required to build zql")? (<unknown>, line 5)']
# Row 11365:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 7)']
# Row 11453:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 9)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 9)']
# Row 11572:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(__doc__ % sys.argv[0])? (<unknown>, line 5)"]
# Row 11607:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 11)']
# Row 11608:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 9)']
# Row 11612:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 9)']
# Row 11617:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(params['uids'])? (<unknown>, line 5)"]
# Row 11618:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 12)']
# Row 11713:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11714:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11715:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11716:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11717:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11718:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11719:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11720:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Downloading page %s .."%url)? (<unknown>, line 4)']
# Row 11721:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 11722:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 11868:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 6)']
# Row 11869:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 6)']
# Row 12578:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('DOCTYPE: html')? (<unknown>, line 8)"]
# Row 12579:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 24)']
# Row 12580:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(cmd)? (<unknown>, line 7)"]
# Row 12602:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 16)']
# Row 12608:
#   Docstrings found: ['AST parse error: inconsistent use of tabs and spaces in indentation (<unknown>, line 8)']
# Row 12613:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('created %s' % tmp_cleansed_path)? (<unknown>, line 12)"]
# Row 12614:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(pipeline_cmd)? (<unknown>, line 11)"]
# Row 12616:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 47)']
# Row 12682:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 21)']
# Row 12718:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 11)']
# Row 12719:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(output, valid, result)? (<unknown>, line 20)"]
# Row 12730:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 15)']
# Row 12910:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12911:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12913:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 8)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 8)']
# Row 12914:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 12915:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 12916:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12921:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12950:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12951:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12952:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 12953:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 12954:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 5)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 5)']
# Row 13119:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(result)? (<unknown>, line 9)"]
# Row 13236:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 4)']
# Row 13238:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 6)']
# Row 13240:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 5)']
# Row 13340:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Generating the Record Collection...\\n')? (<unknown>, line 4)"]
# Row 13390:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 5)']
# Row 13391:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 14)']
# Row 13420:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Starting job # %s in a separate thread.' % job.num)? (<unknown>, line 27)"]
# Row 13422:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('%s jobs:' % name)? (<unknown>, line 5)"]
# Row 13423:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 7)']
# Row 13493:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Object `%s` not found.' % oname)? (<unknown>, line 15)"]
# Row 13507:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("------> " + cmd)? (<unknown>, line 14)']
# Row 13523:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 17)']
# Row 13607:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 26)']
# Row 13608:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 13)']
# Row 13609:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Class parameters")? (<unknown>, line 9)']
# Row 13610:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Examples")? (<unknown>, line 5)']
# Row 13643:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 9)']
# Row 13662:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 6)']
# Row 13669:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 26)']
# Row 13671:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("No answer for 5s:", end=" ")? (<unknown>, line 15)']
# Row 13680:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("No partition exists.")? (<unknown>, line 5)']
# Row 13683:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print(\'<< Starting interactive mode >>\', end=" ")? (<unknown>, line 51)']
# Row 13695:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 5)']
# Row 13696:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 13700:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 21)']
# Row 13702:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Corrupt",f,"deleted - hset is not threadsafe!")? (<unknown>, line 18)']
# Row 13916:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Pasting code)? (<unknown>, line 4)']
# Row 13937:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 8)']
# Row 13956:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print(strng)? (<unknown>, line 16)"]
# Row 13957:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Unable to show file',`fname`)? (<unknown>, line 17)"]
# Row 13960:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print(header, end=" ")? (<unknown>, line 8)']
# Row 14004:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 14)']
# Row 14005:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("%autopx enabled")? (<unknown>, line 8)']
# Row 14006:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("%autopx disabled")? (<unknown>, line 7)']
# Row 14135:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 8)']
# Row 14256:
#   Comments found: ['Tokenization error: unindent does not match any outer indentation level (<tokenize>, line 6)']
#   Docstrings found: ['AST parse error: unindent does not match any outer indentation level (<unknown>, line 6)']
# Row 14335:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 20)']
# Row 14342:
#   Docstrings found: ['AST parse error: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 10)']
# Row 14350:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 15)']
# Row 14475:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('size of each batch =', batch_size)? (<unknown>, line 12)"]
# Row 14476:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 17)']
# Row 14477:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 7)']
# Row 14518:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 50)']
# Row 14519:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Logging has not been activated.')? (<unknown>, line 5)"]
# Row 14522:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print("Logging hadn\'t been started.")? (<unknown>, line 8)']
# Row 14562:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 5)']
# Row 14615:
#   Docstrings found: ['AST parse error: Missing parentheses in call to \'print\'. Did you mean print(\'No %s found\' % msg, end=" ")? (<unknown>, line 4)']
# Row 14616:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('Object is not callable.')? (<unknown>, line 5)"]
# Row 14619:
#   Docstrings found: ["AST parse error: Missing parentheses in call to 'print'. Did you mean print('File %r is binary, not printing.' % ofile)? (<unknown>, line 12)"]
# Row 14624:
#   Docstrings found: ['AST parse error: invalid syntax (<unknown>, line 45)']
